# %% [markdown]
# # Effective Pandas: Patterns for Data Manipulation
#
# ## Chapter 5 — Series Deep Dive
#
# **Author:** Matt Harrison
# **Repository:** `technical-books-lab`
# **Notebook purpose:** Reproduce the chapter, experiment with the ideas, and build a reusable personal reference.

# %% [markdown]
# ## Learning Objectives
#
# By the end of this chapter, I should be able to:
#
# - Know and understand What the Series data structure is.
# - How and When to apply this data structure.
# - When to use and not use this data structure.

# %%
# [SETUP] Core imports and environment information

from pathlib import Path

import numpy as np
import pandas as pd


# [PATHS] Resolve repository paths so notebooks work offline
# This works whether Jupyter starts from the repo root or from a subfolder.


def find_repo_root(start: Path | None = None) -> Path:
    start = (start or Path.cwd()).resolve()

    for candidate in (start, *start.parents):
        if (candidate / "pyproject.toml").exists() and (
            candidate / "books" / "pandas"
        ).exists():
            return candidate

    raise FileNotFoundError(
        "Could not find the technical-books-lab repository root. "
        "Open the notebook from somewhere inside the repository."
    )


REPO_ROOT = find_repo_root()
PANDAS_DIR = REPO_ROOT / "books" / "pandas"

RAW_DATA_DIR = PANDAS_DIR / "data" / "raw"
PROCESSED_DATA_DIR = PANDAS_DIR / "data" / "processed"
OUTPUT_DIR = PANDAS_DIR / "outputs"

DATASETS = {
    "vehicles": RAW_DATA_DIR / "vehicles.csv.zip",
    "alta": RAW_DATA_DIR / "alta-noaa-1980-2019.csv",
    "siena_presidents": RAW_DATA_DIR / "siena2018-pres.csv",
    "jetbrains_2020": RAW_DATA_DIR / "2020-jetbrains-python-survey.csv",
    "dirty_devil": RAW_DATA_DIR / "dirtydevil.txt",
    "hanksville": RAW_DATA_DIR / "hanksville.csv",
}

print("Repository:", REPO_ROOT)
print("Raw data:", RAW_DATA_DIR)
print("Processed data:", PROCESSED_DATA_DIR)
print("Outputs:", OUTPUT_DIR)
# Out:
# Repository: C:\Users\Admin\Projects\technical-books-lab
# Raw data: C:\Users\Admin\Projects\technical-books-lab\books\pandas\data\raw
# Processed data: C:\Users\Admin\Projects\technical-books-lab\books\pandas\data\processed
# Outputs: C:\Users\Admin\Projects\technical-books-lab\books\pandas\outputs

# %%
# [BOOK EXAMPLE] 5.1 Loading the data 

import pandas as pd

vehicle_filename = DATASETS["vehicles"]

df = pd.read_csv(vehicle_filename)
city_mpg = df.city08
highway_mpg = df.highway08
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2344\692276583.py:7: DtypeWarning: Columns (68: sCharger, 70: fuelType2, 71: rangeA, 72: evMotor, 73: mfrCode, 74: c240Dscr, 76: c240bDscr, 79: startStop) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(vehicle_filename)

# %%
city_mpg
# Out:
# 0        19
# 1         9
# 2        23
# 3        10
# 4        17
#          ..
# 41139    19
# 41140    20
# 41141    18
# 41142    18
# 41143    16
# Name: city08, Length: 41144, dtype: int64

# %%
highway_mpg
# Out:
# 0        25
# 1        14
# 2        33
# 3        12
# 4        23
#          ..
# 41139    26
# 41140    28
# 41141    24
# 41142    24
# 41143    21
# Name: highway08, Length: 41144, dtype: int64

# %%
# [BOOK EXAMPLE] 5.2 Series attributes: Inspecting the number of attributes are on a series

len(dir(city_mpg))
# Out:
# 392

# %% [markdown]
# ## Key Takeaways
#
# - Pandas object have a large number of attributes and methods.

# %% [markdown]
# ## Chapter Complete
#
# - Key takeaways written
